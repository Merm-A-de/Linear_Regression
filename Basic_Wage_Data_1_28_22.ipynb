# %% [markdown]
# <a href="https://colab.research.google.com/github/Merm-A-de/Linear_Regression/blob/main/Basic_Wage_Data_1_28_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
wage_data = pd.read_csv("https://raw.githubusercontent.com/Merm-A-de/Linear_Regression/main/avg_wage%20(1).csv")

# %%
#US = wage_data(wage_data.Country == "United States")

wage_data
# Out:
#             Country   2000   2005   2010   2011   2012   2013   2014   2015  \
# 0    United States   55366  58092  61048  61132  61634  61347  62263  63845
# 1          Iceland   53810  61187  51234  53452  53137  53966  54736  58377
# 2       Luxembourg   57100  59505  63917  62955  62451  63058  65379  66247
# 3      Switzerland   56529  61063  63277  63533  64582  65431  65548  65910
# 4      Netherlands   52371  54565  57959  57601  57835  58035  57729  58403
# 5          Denmark   46360  50879  54928  54644  54570  54925  55976  56960
# 6           Norway   38647  44438  50586  42347  53777  54853  55121  55404
# 7           Canada   44108  45824  50024  50512  51289  51924  52557  52968
# 8        Australia   45201  48615  51957  53601  53919  53672  54085  53636
# 9          Belgium   51922  52969  53969  54520  54951  55503  55809  55427
# 10         Germany   45584  46553  47054  48026  48683  49159  50001  51172
# ...

# %%
#How to return a dataframe filtered by a condition

# The filter here is which countries on average have a higher wage in year 2020
# than $65,000


wage_data[wage_data['2020']>65000]
# Out:
#           Country   2000   2005   2010   2011   2012   2013   2014   2015  \
# 0  United States   55366  58092  61048  61132  61634  61347  62263  63845
# 1        Iceland   53810  61187  51234  53452  53137  53966  54736  58377
# 2     Luxembourg   57100  59505  63917  62955  62451  63058  65379  66247
#
#     2016   2017   2018   2019   2020
# 0  63942  64618  65303  66383  69392
# 1  62949  69051  72466  70391  67488
# 2  66393  67393  67448  66840  65854

# %%
# The filter here is which countries have seen a doubling (or more) in average 
# wage from 2000 to 2020


wage_data[(wage_data['2020']/wage_data['2000'])>2]
# Out:
#        Country   2000   2005   2010   2011   2012   2013   2014   2015   2016  \
# 25  Lithuania   11927  18261  19742  20177  20517  21321  22268  23715  24982
# 26    Estonia   12744  17661  21991  21483  21808  22327  23528  24633  24932
# 28     Latvia   11759  15913  19385  18698  19472  20444  21899  23742  25154
#
#      2017   2018   2019   2020
# 25  26382  27572  29695  31811
# 26  26417  27920  29948  30720
# 28  26128  27107  28645  29876

# %%
wage_data.loc[(wage_data['2020']/wage_data['2000'])>2]
# Out:
#        Country   2000   2005   2010   2011   2012   2013   2014   2015   2016  \
# 25  Lithuania   11927  18261  19742  20177  20517  21321  22268  23715  24982
# 26    Estonia   12744  17661  21991  21483  21808  22327  23528  24633  24932
# 28     Latvia   11759  15913  19385  18698  19472  20444  21899  23742  25154
#
#      2017   2018   2019   2020
# 25  26382  27572  29695  31811
# 26  26417  27920  29948  30720
# 28  26128  27107  28645  29876

# %%
# looks like you cant run a query on an expressional condition (multiply)

wage_data.query[['2020']/['2000']>2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-42b52f70e072> in <module>
# ----> 1 wage_data.query[['2020']/['2000']>2]
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
# create variable with rows that meet condition

broke = wage_data['2020'] < 25000

# %%
wage_data[broke]
# Out:
#       Country   2000   2005   2010   2011   2012   2013   2014   2015   2016  \
# 33  Slovakia   14368  16589  19858  19689  19437  19590  19980  20771  21430
# 34    Mexico   16111  17484  16407  16555  16258  16271  16302  16516  16322
#
#      2017   2018   2019   2020
# 33  22072  22692  23438  23619
# 34  16277  16637  16771  16230

# %%
wage_data[(wage_data['2020']>50000)&(wage_data['2015']>50000)]
# Out:
#            Country   2000   2005   2010   2011   2012   2013   2014   2015  \
# 0   United States   55366  58092  61048  61132  61634  61347  62263  63845
# 1         Iceland   53810  61187  51234  53452  53137  53966  54736  58377
# 2      Luxembourg   57100  59505  63917  62955  62451  63058  65379  66247
# 3     Switzerland   56529  61063  63277  63533  64582  65431  65548  65910
# 4     Netherlands   52371  54565  57959  57601  57835  58035  57729  58403
# 5         Denmark   46360  50879  54928  54644  54570  54925  55976  56960
# 6          Norway   38647  44438  50586  42347  53777  54853  55121  55404
# 7          Canada   44108  45824  50024  50512  51289  51924  52557  52968
# 8       Australia   45201  48615  51957  53601  53919  53672  54085  53636
# 9         Belgium   51922  52969  53969  54520  54951  55503  55809  55427
# 10        Germany   45584  46553  47054  48026  48683  49159  50001  51172
# ...

# %%
#find the max value in each column 
column_names = []

for col in wage_data:
  column_names.append(col)


print(column_names)
# Out:
# ['Country', '2000', '2005', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

# %%
for x in column_names:
# Out:
#   File "<ipython-input-157-473a5325be76>", line 1
#     for x in column_names:
#                           ^
# SyntaxError: unexpected EOF while parsing

# %%
wage_data[wage_data[]]

# %%
# how to order the results ( only for the measured column) 
wage_data['2020'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0     69392
# 1     67488
# 2     65854
# 3     64824
# 4     58828
# 5     58430
# 6     55780
# 7     55342
# 8     55206
# 9     54237
# 10    53745
# 11    53132
# 12    49474
# 13    47147
# 14    47020
# 15    46230
# 16    45581
# 17    45269
# 18    41960
# 19    41445
# 20    39322
# 21    38515
# 22    37922
# 23    37769
# 24    32527
# 25    31811
# 26    30720
# 27    29885
# 28    29876
# 29    28410
# 30    27207
# 31    26729
# 32    25410
# 33    23619
# 34    16230
# Name: 2020, dtype: int64>

# %%
# find the max for 1 individual row, and return all columns of that row

# %%
wage_data.query('2020 > 62000 & 2000 > 30000')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-02982f2c8e58> in <module>
# ----> 1 wage_data.query('2020 > 62000 & 2000 > 30000')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4061
#    4062         try:
# -> 4063             result = self.loc[res]
#    4064         except ValueError:
#    4065             # when res is multi-dimensional loc raises, but this is sometimes a
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
plt.scatter(wage_data.2020)
# Out:
#   File "<ipython-input-79-1b0395d21861>", line 1
#     plt.scatter(wage_data.2020)
#                          ^
# SyntaxError: invalid syntax

# %%
united_States = wage_data.head(1)

united_States
# Out:
#           Country   2000   2005   2010   2011   2012   2013   2014   2015  \
# 0  United States   55366  58092  61048  61132  61634  61347  62263  63845
#
#     2016   2017   2018   2019   2020
# 0  63942  64618  65303  66383  69392

# %%
tte = wage_data.head(2)

tte
# Out:
#           Country   2000   2005   2010   2011   2012   2013   2014   2015  \
# 0  United States   55366  58092  61048  61132  61634  61347  62263  63845
# 1        Iceland   53810  61187  51234  53452  53137  53966  54736  58377
#
#     2016   2017   2018   2019   2020
# 0  63942  64618  65303  66383  69392
# 1  62949  69051  72466  70391  67488

# %%
plt.scatter(column_names[1:], (united_States.T[1:], ))
plt.xlabel("Year (2000 - 2020) ")
plt.ylabel("Average Income ($)")
plt.show()

# %%
model = sm.OLS.from_formula('Averge Income ~ Year', data = united_States)


results = model.fit()


print(results.params)
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-156-acdf23116ae5>", line 1, in <module>
#     model = sm.OLS.from_formula('Averge Income ~ Year', data = united_States)
#
#   File "/usr/local/lib/python3.8/dist-packages/statsmodels/base/model.py", line 169, in from_formula
#     tmp = handle_formula_data(data, None, formula, depth=eval_env,
#
#   File "/usr/local/lib/python3.8/dist-packages/statsmodels/formula/formulatools.py", line 63, in handle_formula_data
#     result = dmatrices(formula, Y, depth, return_type='dataframe',
#
#   File "/usr/local/lib/python3.8/dist-packages/patsy/highlevel.py", line 309, in dmatrices
#     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#
#   File "/usr/local/lib/python3.8/dist-packages/patsy/highlevel.py", line 164, in _do_highlevel_design
# ...

# %%
# Out:
#                   2000   2005   2010   2011   2012   2013   2014   2015  \
# Country
# United States    55366  58092  61048  61132  61634  61347  62263  63845
# Iceland          53810  61187  51234  53452  53137  53966  54736  58377
# Luxembourg       57100  59505  63917  62955  62451  63058  65379  66247
# Switzerland      56529  61063  63277  63533  64582  65431  65548  65910
# Netherlands      52371  54565  57959  57601  57835  58035  57729  58403
# Denmark          46360  50879  54928  54644  54570  54925  55976  56960
# Norway           38647  44438  50586  42347  53777  54853  55121  55404
# Canada           44108  45824  50024  50512  51289  51924  52557  52968
# Australia        45201  48615  51957  53601  53919  53672  54085  53636
# Belgium          51922  52969  53969  54520  54951  55503  55809  55427
# Germany          45584  46553  47054  48026  48683  49159  50001  51172
# Austria          47860  49764  52334  51755  52071  52128  52310  52686
# ...

# %%
plt.scatter(column_names[1:], (tte.T[1:]))
plt.xlabel("Year (2000 - 2020) ")
plt.ylabel("Average Income ($)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-57550a6f27bf> in <module>
# ----> 1 plt.scatter(column_names[1:], (tte.T[1:]))
#       2 plt.xlabel("Year (2000 - 2020) ")
#       3 plt.ylabel("Average Income ($)")
#       4 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
len(tte.T)
# Out:
# 14

# %%
np.array
# Out:
# <function numpy.array>

# %%
Usa =wage_data[wage_data['Country']=='United States']
#x=pd.DataFrame([Usa.iloc[0].index,Usa.iloc[0].values]).T
#x.iloc[1:].plot()
#plt.show() 

Usa
# Out:
# Empty DataFrame
# Columns: [Country, 2000, 2005, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# Index: []

# %%
new_index = wage_data.set_index('Country') 

new_index
# Out:
#                   2000   2005   2010   2011   2012   2013   2014   2015  \
# Country
# United States    55366  58092  61048  61132  61634  61347  62263  63845
# Iceland          53810  61187  51234  53452  53137  53966  54736  58377
# Luxembourg       57100  59505  63917  62955  62451  63058  65379  66247
# Switzerland      56529  61063  63277  63533  64582  65431  65548  65910
# Netherlands      52371  54565  57959  57601  57835  58035  57729  58403
# Denmark          46360  50879  54928  54644  54570  54925  55976  56960
# Norway           38647  44438  50586  42347  53777  54853  55121  55404
# Canada           44108  45824  50024  50512  51289  51924  52557  52968
# Australia        45201  48615  51957  53601  53919  53672  54085  53636
# Belgium          51922  52969  53969  54520  54951  55503  55809  55427
# Germany          45584  46553  47054  48026  48683  49159  50001  51172
# Austria          47860  49764  52334  51755  52071  52128  52310  52686
# ...

# %%
plt.bar(new_index.index,new_index['2000'])
plt.figure(figsize=(100,120))

# %%
# how to only return certain columns

# %%
wage_data[wage_data['Country']== 'Iceland']
# Out:
# Empty DataFrame
# Columns: [Country, 2000, 2005, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# Index: []

# %%
# how to select a row by filter for a non numerical condition (name == ? )
